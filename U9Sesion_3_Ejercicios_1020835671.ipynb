# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelCastro-98/Portafolio/blob/main/U9Sesion_3_Ejercicios_1020835671.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **UNIDAD 9 SESION 3 EJERCICIO 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url= "https://drive.google.com/uc?export=download&id=1VbrQjDF2Br0tjHHiruUnp-0qmnQwon1I"
df = pd.read_csv(url)

df['Edad'] = pd.to_numeric(df['Edad'])
df['Ingreso Mensual'] = pd.to_numeric(df['Ingreso Mensual'])

plt.figure(figsize=(10, 6))
sns.regplot(x='Edad', y='Ingreso Mensual', data=df)


plt.xlabel('Edad')
plt.ylabel('Ingreso Mensual')
plt.title('Relación entre Edad e Ingreso Mensual')

plt.show()

# %% [markdown]
# **UNIDAD 9 SESION 3 EJERCICIO 2**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url= "https://drive.google.com/uc?export=download&id=1VbrQjDF2Br0tjHHiruUnp-0qmnQwon1I"
df = pd.read_csv(url)

df['Gasto Mensual'] = pd.to_numeric(df['Gasto Mensual'])

gasto_por_region = df.groupby('Region')['Gasto Mensual'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Gasto Mensual', data=gasto_por_region)

plt.xlabel('Región')
plt.ylabel('Gasto Mensual Promedio')
plt.title('Gasto Mensual Promedio por Región')

plt.show()

# %% [markdown]
# **UNIDAD 9 SESION 3 EJERCICIO 3**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url= "https://drive.google.com/uc?export=download&id=1VbrQjDF2Br0tjHHiruUnp-0qmnQwon1I"
df = pd.read_csv(url)


df['Ingreso Mensual'] = pd.to_numeric(df['Ingreso Mensual'])
df['Gasto Mensual'] = pd.to_numeric(df['Gasto Mensual'])


plt.figure(figsize=(10, 6))

sns.histplot(df['Ingreso Mensual'], color='skyblue', label='Ingreso Mensual', kde=True, alpha=0.6)
sns.histplot(df['Gasto Mensual'], color='lightcoral', label='Gasto Mensual', kde=True, alpha=0.6)


plt.xlabel('Monto')
plt.ylabel('Frecuencia')
plt.title('Distribución de Ingreso Mensual y Gasto Mensual')
plt.legend()

plt.show()

# %% [markdown]
# **UNIDAD 9 SESION 3 EJERCICIO 4**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url= "https://drive.google.com/uc?export=download&id=1VbrQjDF2Br0tjHHiruUnp-0qmnQwon1I"
df = pd.read_csv(url)

df['Puntuacion de credito'] = pd.to_numeric(df['Puntuacion de credito'])
df['Ingreso Mensual'] = pd.to_numeric(df['Ingreso Mensual'])

plt.figure(figsize=(12, 8))
sns.boxplot(x='Puntuacion de credito', y='Ingreso Mensual', data=df)

sns.swarmplot(x='Puntuacion de credito', y='Ingreso Mensual', data=df, color=".25")

plt.xlabel('Puntuación de Crédito')
plt.ylabel('Ingreso Mensual')
plt.title('Relación entre Puntuación de Crédito e Ingreso Mensual')
plt.xticks(rotation=60, ha='right')

plt.show()

# %% [markdown]
# **UNIDAD 9 SESION 3 EJERCICIO 5**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url= "https://drive.google.com/uc?export=download&id=1VbrQjDF2Br0tjHHiruUnp-0qmnQwon1I"
df = pd.read_csv(url)

df['Puntuacion de credito'] = pd.to_numeric(df['Puntuacion de credito'])
df['Ingreso Mensual'] = pd.to_numeric(df['Ingreso Mensual'])

plt.figure(figsize=(12, 8))
sns.boxplot(x='Puntuacion de credito', y='Ingreso Mensual', data=df)

sns.swarmplot(x='Puntuacion de credito', y='Ingreso Mensual', data=df, color=".25")

plt.xlabel('Puntuación de Crédito')
plt.ylabel('Ingreso Mensual')
plt.title('Relación entre Puntuación de Crédito e Ingreso Mensual')
plt.xticks(rotation=60, ha='right')


plt.show()
